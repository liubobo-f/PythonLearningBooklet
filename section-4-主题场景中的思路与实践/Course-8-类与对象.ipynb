# %% [markdown]
# # 类与对象

# %%
# 修改print实例的输出，让输出结果更有意义
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __str__(self):
        return f"Person(name={self.name}, age={self.age})"

person = Person("John", 30)
print(person)
# Out:
# Person(name=John, age=30)

# %%
# 定义__format__方法，用来控制格式化输出
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def __format__(self, format_spec):
        if format_spec == 'name':
            return self.name
        elif format_spec == 'age':
            return str(self.age)
        else:
            return f'{self.name} ({self.age})'

p = Person('Alice', 25)
print(f'{p:name}',f'{p:age}')
print(format(p, 'e'))
# Out:
# Alice 25
# Alice (25)

# %%
# 定义__enter__和__exit__方法，可以管理对象被With语句块包裹的整个生命周期。
class MyContextManager:
    def __enter__(self):
        print("Entering the context manager")
        return self

    def __exit__(self, exc_type, exc_val, exc_tb):
        print("Exiting the context manager")


with MyContextManager() as cm:
    print("Inside the context manager")
# Out:
# Entering the context manager
# Inside the context manager
# Exiting the context manager

# %%
# 调用父类中的方法，可以使用super()
class Animal:
    def __init__(self, name):
        self.name = name

    def eat(self):
        print(f"{self.name} is eating.")


class Dog(Animal):
    def __init__(self, name, breed):
        super().__init__(name)

    def bark(self):
        print(f"{self.name} is barking.")

dog = Dog("Max", "Labrador")
dog.eat()
# Out:
# Max is eating.

# %%
# 定义抽象基类，明确继承它的子类必须实现的方法
# 可以使用abc模块
from abc import ABCMeta, abstractmethod
class baseClass(metaclass=ABCMeta):
    @abstractmethod
    def func(self):
        pass

# 这种基类不能实例化，继承这个基类的子类必须实现func方法

# %%
# 让类支持比较操作，可以定义__eq__()等方法
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    # 比较两个对象是否相等
    def __eq__(self, other):
        return self.name == other.name and self.age == other.age

    # 比较两个对象是否不相等
    def __ne__(self, other):
        return not self.__eq__(other)

    # 当前对象是否小于另一个对象
    def __lt__(self, other):
        return self.age < other.age
    
p1 = Person('Alice', 25)
p2 = Person('Bob', 30)
print(p1 < p2)
# Out:
# True
