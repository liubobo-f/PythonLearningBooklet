# %% [markdown]
# # 数据类型
#
# 每个变量对应一个数据类型。PYTHON内置许多不同的数据类型，如整数、浮点数、布尔值和字符串等，还可以自定义类型。type()函数可以查看变量的数据类型。

# %%
# 整数类型int
var = 5
print(var,type(var))
# Out:
# 5 <class 'int'>

# %%
# 浮点数类型 float，即小数或分数
pi1 = 22/7
pi2 = 3.14
print(pi1,pi2)
print(type(pi1),type(pi2))
# Out:
# 3.142857142857143 3.14
# <class 'float'> <class 'float'>

# %%
# 布尔值类型 bool, 只有True和False两种值
var_bool = True
print(var_bool,type(var_bool))

var_bool2 = var<pi2 # 判断5<3.14，返回True或False
print(var_bool2,type(var_bool2))
# Out:
# True <class 'bool'>
# False <class 'bool'>

# %%
print(bool(0),bool(None))
# Out:
# False False

# %%
# 布尔值可以进行and,or,not等运算，结果也是布尔值。
print(var_bool and var_bool2) # True and False
print(var_bool or var_bool2) # True or False
print(not var_bool) # not True
# Out:
# False
# True
# False

# %%
# 字符串类型
s = "Hello World"
print(s,type(s))
s1 = "73"
print(s1,type(s1))
# Out:
# Hello World <class 'str'>
# 73 <class 'str'>

# %%
# 可以用len()函数来计算字符串长度
print(len(s),len(s1)) 
# 可以用+号来连接字符串
print(s+s1)
# 可以用*号来重复字符串
print(s*3)
# Out:
# 11 2
# Hello World73
# Hello WorldHello WorldHello World

# %% [markdown]
# 不同类型的变量之间通常无法进行比较等运算。

# %%
print(3>"2") # 数值无法直接与字符串比较
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 print(3>"2") # 数值无法直接与字符串比较
#
# TypeError: '>' not supported between instances of 'int' and 'str'

# %% [markdown]
# 变量之间可以相互转化，比如把一个字符串变量转化成数字变量，或者把一个数字变量转化成字符串变量。

# %%
print(int("73"))
print(str(70+3)+" is my lucky number")

# %% [markdown]
# 类型不匹配是一种非常常见的错误，Python在一些场景下会自动进行类型转换，但有时会报错。

# %%
print(73+" is my lucky number")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 print(73+" is my lucky number")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# 每种数据类型都有自己的方法，比如对于一个字符串变量s
# 可以用s.upper()来将s中的字母全部转换为大写
s = "hello world"
print(s.upper())
# 实用某种类型的方法，在变量后面加一个点
# 然后加上方法名，再加上括号，括号里面是方法的参数

#如果你想不起某个类型有什么方法，可以先输入对应类型的变量，然后输入一个点
# Python会自动提示这个类型的方法

# %%
# Out:
# type
