# %% [markdown]
# # 函数
# Notebook中的代码块有非常好的结构性，可以很方便的进行代码块的移动、复制、粘贴等操作。
# 函数就是一种特殊的代码块，你可以把多行代码封装成一个函数，然后重复使用。
#
# Python内置了丰富的函数，比如print()、input()、len()等。
# 你也可以自己定义函数，函数的定义格式如下：

# %%
# 函数的创建方法
def add3_and_print(input_var):
    result = input_var + 3
    print(result)
    return result


# 其中def是定义函数的关键字
# add3_and_print是函数的名字，input_var是函数的参数，result是函数的返回值。
# 通过return关键字返回函数的返回值。
# 函数的计算过程需要缩进，Python以缩进来判断代码的层次结构。

# %% [markdown]
# 这个函数可以接收一个数字，加3，打印，再返回加3后的结果。
# 其中开头的def定义了函数名，括号里是函数的参数，冒号后面是函数体。
# 函数体要缩进，包含了调用函数时的操作。
# 最后一行retuan 是函数运行后，返回的计算结果。
#
# 定义部分并不会执行函数，只有调用函数时才会执行。

# %%
# 调用刚刚的函数
a = add3_and_print(1)
print("打印结果",a)
# Out:
# 4
# 打印结果 4

# %% [markdown]
# 结果中第一行是函数内部打印的result变量，第二行是函数外部print函数的结果。
# 每次调用函数，都会使用已经定义好的代码块进行运算。
# 另外，return并不是函数必须的，如果函数没有return，那么函数的返回值就是None，函数中的代码块会全部执行，但是不会返回任何值。

# %%
def showPI():
    print("PI = ", 3.1415926)

showPI()
# Out:
# PI =  3.1415926

# %% [markdown]
# 举个例子，如果收入sallary需要交3%的税，我们可以设计一个sallary_after_tax函数，计算税后收入。

# %%
def sallary_after_tax(sallary):
    return sallary*0.97

print(sallary_after_tax(10000))
# Out:
# 9700.0

# %% [markdown]
# 函数的参数可以设定默认值，这样调用函数时，可以不传入参数，直接使用默认值。

# %%
def greet(name="刘波波"):
    print("Hello,", name)
    
greet()
greet("World") # 如果只有一个参数，参数的名字可以省略
greet(name = "World")
# Out:
# Hello, 刘波波
# Hello, World
# Hello, World

# %% [markdown]
# 函数可以没有参数，也可以有1个以上的参数。

# %%
# 这是一个计算体积的函数
def volume(length, width, height):
    return length * width * height

print(volume(2, 3, 4))
# Out:
# 24

# %%
# 这是一个没有参数的函数
def greeting():
    print("Hello World!")

greeting()
# Out:
# Hello World!
# Hello World!
# Hello World!
